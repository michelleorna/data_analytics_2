# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleorna/data_analytics_2/blob/main/Python/Unit%202%20Assignments/Unit2_L6_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1
#Create a simple dictionary that stores 2 variables, for example: first and last name.
name={"first_name":'Noemi', "last_name":'Orna'}
#Q2 Print out those variables stored in your previous dictionary.
print(name['first_name'], name['last_name'])
#Q3 Add a message to those variables on printing: for example: “Hello, firstname lastname!”
print("Hello, " + name['first_name'] + " " + name['last_name'] + "!" )
# Out:
# Noemi Orna
# Hello, Noemi Orna!

# %%
#Q4 Create a dictionary that holds 2 key:value pairs
    #a. Look through your dictionary and print each pair.
pets={'dog':'Kimbo', 'cat':'Milo'}
for pet, value in pets.items():
  print(pet,value)
# Out:
# dog Kimbo
# cat Milo

# %%
#Q5 Create a nested dictionary containing 3 dictionaries. 
  #a. Loop through the dictionaries and print a message for each 
travel={'Europe':{'Spain':'Madrid'}, 'Asia':{'Japan':'Tokyo'}, 'Africa':{'Egypt':'Cairo'}}
for destination,val in travel.items():
  if type(val) is dict:
    for nesCountry, nesCity in val.items():
      print ('I want to visit '+nesCountry+' especially their capital',nesCity)
  else:
    print("Unknown place")
# Out:
# I want to visit Spain especially their capital Madrid
# I want to visit Japan especially their capital Tokyo
# I want to visit Egypt especially their capital Cairo
