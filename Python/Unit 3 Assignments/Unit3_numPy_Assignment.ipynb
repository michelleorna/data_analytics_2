# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleorna/data_analytics_2/blob/main/Python/Unit%203%20Assignments/Unit3_numPy_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3 - Advanced Python - NumPy - Assingment #1

# %% [markdown]
# ## 1. Environment Set up

# %%
import pandas as pd
import matplotlib.pyplot as plt

olympics = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/olympics.csv')

# %%
import numpy as np
#Dataset from summer Olympic London, year 2012
np_olympic_country = np.array(['GBR','China','RUS','US','KOR','JPN','GER'])
np_olympic_country_Gold = np.array([29,38,24,46,13,7,11])
np_olympic_country_Silver = np.array([17,28,25,28,8,14,11])
np_olympic_country_Bronze = np.array([19,22,32,29,7,17,14])

# %% [markdown]
# ## 2.	Find country with maximum gold

# %%
country_with_max_gold = np_olympic_country[np_olympic_country_Gold.argmax()]

# %%
print(country_with_max_gold)
# Out:
# US

# %% [markdown]
# ## 3.	Find countries with more than 20 gold medals

# %%
 more20_medals=np_olympic_country[np_olympic_country_Gold>20]

# %%
print(more20_medals)
# Out:
# ['GBR' 'China' 'RUS' 'US']
