# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleorna/data_analytics_2/blob/main/Evenodd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ask the user for a number. Depending on whether the number is even or odd, print out an appropriate message to the user.

# %%
number = int(input("Enter a number to see if even or odd: "))
x=number%2
if (x) == 0:
   print("{0} is Even".format(number))
else:
   print("{0} is Odd".format(number))
# Out:
# Enter a number to see if even or odd: 8
# 8 is Even
